# %%
"""
    Maps Standings only
"""
# Out:
# '\n    Maps Standings only\n'

# %%
import json
import os
import pandas as pd
from pandas import json_normalize

# %%
# Historicity: multi season directory
year_window = 1
start_season = 2015
seasons = list(range(start_season, start_season - year_window, -1))
print(seasons)
# Out:
# [2015]

# %%
# Multi League directory
country = 'ES'
dirCountry = '../' + country + '/'

# %%
league = '140'
season = '2015'

# %%
# League directory
dirName = dirCountry + league + '/'

# %%
# The last week played
curr_week = 38

# %%
df = pd.DataFrame()
curr_standings = None

# Principal leagues are sorted ascendent
dirLeague = sorted(os.listdir(dirCountry))

for league in dirLeague:
    if league == ".DS_Store":
        continue
    if "csv" in league:
        continue
    for season in seasons:
        dirName = dirCountry + league + '/' + str(season) + '/' 
        for subdir in os.listdir(dirName):
            if subdir == ".DS_Store":
                continue
            if subdir == "teams.json":
                continue
            if ".csv" in subdir:
                continue
            
            team_id = subdir
            # Entering directory of a team
            dirTeam = dirName + team_id + '/'
            
            # Reading current standing
            json_standings = dirTeam + team_id + '_' + str(curr_week) + '.json'
            with open(json_standings) as f:
                curr_standings = json.load(f)
            # Adding league
            curr_standings.update({"league": int(league)})
            # Adding season
            curr_standings.update({"season": season})
            # Adds current standing to dataframe
            df = df.append(json_normalize(curr_standings))

# %%
df.head(10)
# Out:
#    rank  points  goals_diff   form                       description    group  \
# 0     4      64           9  LLWDL  UEFA Champions League Qualifiers  La Liga
# 0    11      44          -8  LDLWL                              None  La Liga
# 0    17      39         -22  WDWLW                              None  La Liga
# 0     8      48           3  WLWLD                              None  La Liga
# 0    12      44          -2  LLLDW                              None  La Liga
# 0    10      45         -18  WDLLW                              None  La Liga
# 0    15      42         -16  LWLDL                              None  La Liga
# 0    16      39         -23  LWWLW                              None  La Liga
# 0     1      91          83  WWWWW             UEFA Champions League  La Liga
# 0    13      43         -12  LDLDL                              None  La Liga
#
#    league  season team.id            team.name  ...  \
# 0     140    2015     533           Villarreal  ...
# 0     140    2015     534           Las Palmas  ...
# 0     140    2015     731       Sporting Gijon  ...
# 0     140    2015     535               Malaga  ...
# 0     140    2015     532             Valencia  ...
# 0     140    2015     543           Real Betis  ...
# 0     140    2015     544  Deportivo La Coruna  ...
# 0     140    2015     715           Granada CF  ...
# 0     140    2015     529            Barcelona  ...
# 0     140    2015     545                Eibar  ...
#
#    stats_away.avg_goals_against  stats_away.clean_sheet  \
# 0                           1.2                       7
# 0                           1.9                       3
# 0                           1.8                       3
# 0                           1.1                       5
# 0                           1.3                       2
# 0                           1.5                       6
# 0                           1.4                       3
# 0                           2.0                       1
# 0                           0.8                       9
# 0                           2.1                       3
#
#    stats_away.failed_to_score  stats_away.streaks.wins  \
# 0                           9                        6
# 0                           6                        3
# 0                          10                        2
# 0                          11                        4
# 0                           7                        3
# 0                           7                        2
# 0                           5                        2
# 0                           7                        2
# 0                           2                       12
# 0                           6                        4
#
#    stats_away.streaks.draws  stats_away.streaks.loses  \
# 0                         2                         2
# 0                         2                         3
# 0                         2                         5
# 0                         2                         3
# 0                         3                         4
# 0                         3                         3
# 0                         5                         3
# 0                         4                         4
# 0                         2                         3
# 0                         2                         4
#
#    stats_away.streaks.best_win  stats_away.streaks.best_lose  \
# 0                          1-3                           1-3
# 0                          1-3                           1-3
# 0                          2-3                           2-3
# 0                          1-2                           1-2
# 0                          1-5                           1-5
# 0                          0-3                           0-3
# 0                          1-3                           1-3
# 0                          1-4                           1-4
# 0                          0-8                           0-8
# 0                          0-4                           0-4
#
#    stats_away.streaks.best_goals_for  stats_away.streaks.best_goals_against
# 0                                  3                                      4
# 0                                  3                                      4
# 0                                  3                                      6
# 0                                  3                                      3
# 0                                  5                                      3
# 0                                  3                                      5
# 0                                  3                                      5
# 0                                  4                                      5
# 0                                  8                                      4
# 0                                  4                                      5
#
# [10 rows x 44 columns]

# %%
df.shape
# Out:
# (20, 44)

# %%
# csv to save
file_title = str(season) + '.csv'
csv_file = dirName + file_title
print(file_title)
print(csv_file)
# Out:
# 2015.csv
# ../ES/140/2015/2015.csv

# %%
df.to_csv(csv_file)
