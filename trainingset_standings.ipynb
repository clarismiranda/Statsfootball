# %%
"""
    Maps Standings only
"""
# Out:
# '\n    Maps Standings only\n'

# %%
import json
import os
import pandas as pd
from pandas import json_normalize

# %%
# Historicity: multi season directory
year_window = 1
start_season = 2019
seasons = list(range(start_season, start_season - year_window, -1))
print(seasons)
# Out:
# [2019]

# %%
# Multi League directory
country = 'ES'
dirCountry = '../' + country + '/'

# %%
league = '140'
season = '2019'

# %%
# League directory
dirName = dirCountry + league + '/'

# %%
# The last week played
curr_week = 38

# %%
df = pd.DataFrame()
curr_standings = None

# Principal leagues are sorted ascendent
dirLeague = sorted(os.listdir(dirCountry))

for league in dirLeague:
    if league == ".DS_Store":
        continue
    if "csv" in league:
        continue
    for season in seasons:
        dirName = dirCountry + league + '/' + str(season) + '/' 
        for subdir in os.listdir(dirName):
            if subdir == ".DS_Store":
                continue
            if subdir == "teams.json":
                continue
            if ".csv" in subdir:
                continue
            
            team_id = subdir
            # Entering directory of a team
            dirTeam = dirName + team_id + '/'
            
            # Reading current standing
            json_standings = dirTeam + team_id + '_' + str(curr_week) + '.json'
            with open(json_standings) as f:
                curr_standings = json.load(f)
            # Adding league
            curr_standings.update({"league": int(league)})
            # Adding season
            curr_standings.update({"season": season})
            # Adds current standing to dataframe
            df = df.append(json_normalize(curr_standings))

# %%
df.head(10)
# Out:
#    rank  points  goals_diff   form  \
# 0     5      60          14  WLLWL
# 0    19      33         -25  DLLWL
# 0     9      53          -7  LWLWD
# 0    15      41         -12  LLLWD
# 0     7      56           7  WWLWD
# 0     2      82          48  WLWWW
# 0    14      42         -17  LWWDL
# 0    16      39         -25  LWDLL
# 0    18      36         -21  DWWDW
# 0     3      70          24  DWWDW
#
#                                   description             group  league  \
# 0     Promotion - Europa League (Group Stage)  Primera División     140
# 0                        Relegation - LaLiga2  Primera División     140
# 0                                        None  Primera División     140
# 0                                        None  Primera División     140
# 0   Promotion - Europa League (Qualification)  Primera División     140
# 0  Promotion - Champions League (Group Stage)  Primera División     140
# 0                                        None  Primera División     140
# 0                                        None  Primera División     140
# 0                        Relegation - LaLiga2  Primera División     140
# 0  Promotion - Champions League (Group Stage)  Primera División     140
#
#    season team.id        team.name  ...  stats_away.avg_goals_against  \
# 0    2019     533       Villarreal  ...                           1.3
# 0    2019     798         Mallorca  ...                           2.3
# 0    2019     532         Valencia  ...                           1.9
# 0    2019     543       Real Betis  ...                           1.7
# 0    2019     715       Granada CF  ...                           1.5
# 0    2019     529        Barcelona  ...                           1.2
# 0    2019     545            Eibar  ...                           1.6
# 0    2019     542           Alaves  ...                           2.1
# 0    2019     537          Leganes  ...                           1.3
# 0    2019     530  Atletico Madrid  ...                           0.8
#
#    stats_away.clean_sheet  stats_away.failed_to_score  \
# 0                       5                           1
# 0                       0                          11
# 0                       1                           8
# 0                       3                           9
# 0                       5                           7
# 0                       7                           5
# 0                       5                           9
# 0                       2                           8
# 0                       4                           9
# 0                       7                           5
#
#    stats_away.streaks.wins  stats_away.streaks.draws  \
# 0                        3                         1
# 0                        2                         1
# 0                        2                         2
# 0                        3                         2
# 0                        3                         2
# 0                        5                         2
# 0                        2                         2
# 0                        2                         2
# 0                        2                         2
# 0                        4                         3
#
#    stats_away.streaks.loses  stats_away.streaks.best_win  \
# 0                         3                          0-3
# 0                         3                          1-2
# 0                         3                          2-4
# 0                         2                          1-2
# 0                         3                          0-3
# 0                         1                          0-5
# 0                         4                          0-2
# 0                         6                          0-2
# 0                         4                          0-2
# 0                         1                          0-5
#
#    stats_away.streaks.best_lose  stats_away.streaks.best_goals_for  \
# 0                           0-3                                  3
# 0                           1-2                                  3
# 0                           2-4                                  4
# 0                           1-2                                  2
# 0                           0-3                                  4
# 0                           0-5                                  5
# 0                           0-2                                  2
# 0                           0-2                                  2
# 0                           0-2                                  2
# 0                           0-5                                  5
#
#    stats_away.streaks.best_goals_against
# 0                                      3
# 0                                      5
# 0                                      5
# 0                                      5
# 0                                      4
# 0                                      3
# 0                                      5
# 0                                      6
# 0                                      5
# 0                                      2
#
# [10 rows x 44 columns]

# %%
df.shape
# Out:
# (20, 44)

# %%
# csv to save
file_title = str(season) + '.csv'
csv_file = dirName + file_title
print(file_title)
print(csv_file)
# Out:
# 2019.csv
# ../ES/140/2019/2019.csv

# %%
df.to_csv(csv_file)
